# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
import numpy as np
from torchvision import models
# Out:
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11507.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3282.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11014.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8142.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3614.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5313.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8106.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8118.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4104.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8616.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9740.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1024.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6280.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5283.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4864.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4920.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2222.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5702.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1825.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3106.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11602.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8051.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7179.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3336.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2900.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6593.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6984.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/326.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10351.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11406.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/961.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/36.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11306.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5961.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3634.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5082.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8731.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1132.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5712.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8415.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9459.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4598.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9559.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7558.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8598.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6026.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7364.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5054.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5302.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9348.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4594.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5053.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6206.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/149.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9917.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1709.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9995.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6491.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6219.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11627.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8849.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4273.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11590.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1889.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2934.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10701.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4553.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9889.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11083.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3740.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6828.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8077.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6937.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9601.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10176.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2002.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3889.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5739.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9104.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6502.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5145.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2677.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5756.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9411.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11440.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5856.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2660.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2807.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1070.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2528.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3667.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5210.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8990.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5586.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7717.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3827.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7820.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7894.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10192.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11246.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9622.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4spectrum.png
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4946.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11028.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5841.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/898.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8229.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1957.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6652.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4918.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11683.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6160.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3726.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4791.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8443.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/938.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6514.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2348.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4723.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8968.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8565.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8725.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4928.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4595.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/434.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3507.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10630.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4391.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6723.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3111.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/928.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5348.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3947.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/798.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8645.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5641.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4552.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9224.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4678.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3685.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8444.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/238.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5837.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4542.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9715.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9271.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2833.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3784.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11473.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8005.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/365.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11288.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5250.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3299.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10618.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6856.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9436.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8432.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4716.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9011.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6172.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8664.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5517.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1213.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7458.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/454.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/555.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9909.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4712.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1955.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8575.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2259.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8736.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10348.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11779.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4321.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4657.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5136.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6041.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3511.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8609.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8004.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11463.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11071.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8789.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10167.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9944.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6983.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6796.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3094.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5441.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4065.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7018.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11579.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1642.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4113.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10850.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11671.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/942.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11542.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4603.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11452.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2612.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4652.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3960.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10503.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5128.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11804.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5793.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5373.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8585.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1053.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4551.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3365.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7267.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9263.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8947.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1204.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11114.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2177.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1882.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6184.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8971.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6049.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7618.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7979.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3979.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7072.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8792.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4890.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5401.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1679.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5498.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11368.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/575.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10371.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5000.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8072.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2223.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/554.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8474.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10296.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9424.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/54.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2775.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3598.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10436.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3904.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6684.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/951.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5070.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8047.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1027.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1606.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10013.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1934.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1441.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8220.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1751.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6385.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7303.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2915.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7783.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3525.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9266.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11275.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4995.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11813.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2776.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5255.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2108.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6290.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/181.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/593.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9797.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11474.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/995.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1948.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6605.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9732.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2396.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4535.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9301.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2239.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/182.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7056.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8807.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/380.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7007.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2770.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4858.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10556.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8282.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1880.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9031.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4076.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9362.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1622.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11428.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8364.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11430.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1749.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3389.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8022.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1448.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3029.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/381.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/551.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7779.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1600.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9351.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5477.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/322.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6567.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11140.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3645.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4656.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/42.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1531.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8557.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8461.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11519.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7816.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9996.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/844.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7052.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5030.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3521.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8119.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/15.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/608.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7280.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3559.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5476.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7934.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8089.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4297.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5043.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11769.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3468.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10294.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3758.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11324.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11714.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3002.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5554.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/846.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2128.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1796.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5588.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9059.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3179.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3107.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4565.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9185.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1222.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10765.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9315.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3996.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9434.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4704.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10807.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2123.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6174.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7048.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/262.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10301.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3346.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9840.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11701.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6396.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/793.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4038.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3345.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4279.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2992.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6429.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2851.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2483.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2010.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6941.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4828.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6432.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10901.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4745.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2882.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4154.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6196.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10602.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2013.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4008.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8232.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/off_mel_filter_banks0.png
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6721.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5463.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4692.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6923.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8885.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3892.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3228.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6386.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/939.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11670.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/597.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6956.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11188.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8002.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8335.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10229.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8337.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10291.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6164.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6623.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2350.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5102.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3713.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1074.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6430.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5596.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1192.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1002.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4909.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5009.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10304.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10686.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9246.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2591.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5221.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1320.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9509.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2642.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6350.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4944.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11161.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2245.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2920.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11341.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2202.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2616.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1663.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2458.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3361.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2397.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7833.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11044.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/199.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8032.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9677.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/286.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9312.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9858.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6353.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7598.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4587.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8842.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11704.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3606.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10087.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2193.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11203.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11584.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1013.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11381.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1470.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6144.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10852.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/374.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6426.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6267.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11681.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10418.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4412.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4430.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8352.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9040.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6225.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4805.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3993.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4183.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10703.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3128.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7445.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10504.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7652.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1596.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4285.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4488.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/490.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4810.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8809.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11875.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6051.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8592.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8353.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9425.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6116.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/967.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2058.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8891.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8255.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6795.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/616.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5678.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3293.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2141.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5266.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1859.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9154.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5172.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9083.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10279.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4617.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1277.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6016.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10939.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9026.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9628.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10794.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3622.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1940.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7774.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1544.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11214.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8944.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7868.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4350.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9958.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6102.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2890.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8279.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8275.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11387.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2965.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8762.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9900.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1712.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6777.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5399.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7250.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5304.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2090.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9494.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/819.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/625.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5312.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6209.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1064.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10539.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4012.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6320.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10330.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/141.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8887.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9967.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1897.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10040.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8862.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4588.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4328.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2589.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6176.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5183.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2903.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7864.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6579.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7381.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2487.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6125.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3119.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8216.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2121.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7138.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8907.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3422.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/351.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8236.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3266.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2990.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2120.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4165.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11465.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6402.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1688.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3070.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3037.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9820.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7215.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6636.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7245.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6618.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2655.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5572.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11718.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9535.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/642.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6132.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3593.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3870.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7086.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10977.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5437.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6000.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3309.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1591.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4699.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11320.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/157.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10208.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2742.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10735.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10315.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1162.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4379.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10427.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7724.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11467.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5840.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4349.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3405.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3847.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10413.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8399.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7873.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10575.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1353.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3762.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8676.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9932.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2000.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8718.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7144.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8177.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3103.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7650.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4178.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1spectrum.png
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10446.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8667.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11289.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4646.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6724.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1735.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1462.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9441.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5446.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10096.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/293.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/611.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8601.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1867.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5320.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10995.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9891.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5045.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10066.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9804.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/902.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4073.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11050.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8520.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1292.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8136.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6499.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3746.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2084.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11565.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5360.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2433.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3912.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2639.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3564.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7039.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2481.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11865.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11253.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3791.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2819.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6101.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10433.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4775.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5291.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3300.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7952.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10657.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1087.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7625.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10808.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4375.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7883.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5656.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3894.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/781.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1522.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8568.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3792.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2653.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10983.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2720.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6661.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9482.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1906.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11794.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/349.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2860.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1977.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4788.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/90.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8269.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10580.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9214.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4983.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/180.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1141.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5spectrogram.png
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4149.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7405.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8287.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10722.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9577.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1174.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4806.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11509.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4649.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8763.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4363.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4582.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6213.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4260.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2816.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/626.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4415.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2170.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1547.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11697.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3406.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/619.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4020.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11499.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5677.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10559.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7433.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9892.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7396.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10269.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3763.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5805.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2926.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6935.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11117.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/1765.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3210.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3452.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8713.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7085.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7749.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8936.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5265.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9504.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6356.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9361.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5601.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/5258.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4898.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6205.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7060.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/926.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3173.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/10380.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/7271.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9188.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3908.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3289.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/11422.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9700.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3428.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/3404.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6065.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6168.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/9136.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/6998.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2070.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/2726.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/4755.mp3
# /kaggle/input/compettioon-mp3/train_mp3s/train_mp3s/8304.mp3
# ...
# /kaggle/input/compettioon/feature_npz/feature_npz/5669feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/366feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8940feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8405feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4521feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4613feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3580feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8722feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4352feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3683feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4643feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9733feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3599feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10665feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4325feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2914feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9869feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10544feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8285feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9519feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6490feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1288feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10563feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10739feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6703feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8545feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11223feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1817feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6810feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9199feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5592feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9593feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10509feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10865feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11120feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9314feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5912feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1287feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11375feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7237feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8724feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/409feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6796feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3144feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11538feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7651feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9884feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7704feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3095feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1862feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7541feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2641feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9266feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2557feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8426feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4476feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1182feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1561feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5288feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1262feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1954feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10083feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2488feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7748feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9430feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11703feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6022feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9315feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9397feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1310feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10081feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5760feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9189feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3562feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3665feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2050feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2259feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9762feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5935feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5909feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2060feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10997feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6289feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/376feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7001feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7136feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4239feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7576feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5465feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7788feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3908feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11135feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4182feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6054feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4003feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9302feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2201feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2428feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9422feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11086feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11880feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5971feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7997feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4848feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11544feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1860feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2229feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8429feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3244feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11624feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9661feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6550feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10322feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9676feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/704feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6596feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5435feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9049feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/715feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/533feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9816feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9483feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1620feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4183feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/861feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8457feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8289feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4748feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7346feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5857feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6043feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3697feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8403feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10087feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9837feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9416feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2648feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/981feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/39feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4436feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11359feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2887feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1836feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7775feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8540feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11284feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3054feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9555feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4388feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10586feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8491feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2635feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3213feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/579feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4237feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6828feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9838feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/693feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7667feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10961feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8883feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11188feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3261feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/813feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1605feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5381feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7407feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10404feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3368feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4119feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7848feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1971feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6464feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5710feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4341feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1709feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2901feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4467feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2263feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8186feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11080feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8241feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/578feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6557feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8505feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1653feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9206feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4330feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/709feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8227feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8292feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4292feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5575feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6853feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/633feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7274feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11519feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2237feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6876feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3122feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/327feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5008feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11084feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4567feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/183feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6053feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2778feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3093feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11755feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8961feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8717feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/509feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3595feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2940feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7527feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2650feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10289feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4869feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2788feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4850feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/9097feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11216feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4597feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3364feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/7408feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6741feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4081feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/2176feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/301feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4781feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/8683feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/54feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/5115feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4098feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6221feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/11044feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/4818feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/10381feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6041feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/3135feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/6244feature.npz
# /kaggle/input/compettioon/feature_npz/feature_npz/1251feature.npz

# %%
# process the label data
import numpy as np

# load training labels
label_path = '/kaggle/input/compettioon/train_label.npz'
label = np.load(label_path)

print(list(label.keys())) # labels
train_labels = label['labels']


print(type(train_labels)) #nd array
print(train_labels.shape) #(11886,)
# Out:
# ['labels']
# <class 'numpy.ndarray'>
# (11886,)

# %%
# process the feature data
import numpy as np
# load feature
feature_path = '/kaggle/input/compettioon/feature_npz/feature_npz/'

feature_list = []

for i in range(11886):
    feature = np.load(feature_path + str(i) + "feature.npz")
#     print(list(feature.keys()))
    f = feature['arr_0'].reshape((299,40)) # 299*40
#     print(f.shape)
    feature_list.append(f)
    

feature_combined = np.stack(feature_list, axis=0)
print(feature_combined.shape) # (11886, 299, 40)
# Out:
# (11886, 299, 40)

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class MyDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return len(self.features)

    def __getitem__(self, index):
        feature = self.features[index]
        label = self.labels[index]
        # 确保 feature 是一个二维数组 [height, width]
        feature_tensor = torch.tensor(feature, dtype=torch.float32).unsqueeze(0)  # 添加通道维度，使其成为 [1, height, width]
        label_tensor = torch.tensor(label, dtype=torch.long)
        return feature_tensor, label_tensor




from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature_combined, train_labels, test_size=0.3, random_state=8)


dataset_train = MyDataset(X_train, y_train)
dataset_test = MyDataset(X_test, y_test)


# 使用 DataLoader 进行批处理和数据加载
batch_size = 64
train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset_test, batch_size=batch_size, shuffle=True)

# %%
# process the prediction data
import numpy as np
# load feature
feature_path_pred = '/kaggle/input/compettioon/feature_npz_test/feature_npz_test/'

feature_list_pred = []

for i in range(2447):
    feature_pred = np.load(feature_path_pred + str(i) + "feature.npz")
#     print(list(feature.keys()))
    f1 = feature_pred['arr_0'].reshape((299,40)) # 299*40
#     print(f1.shape)
    feature_list_pred.append(f1)
    

feature_combined_pred = np.stack(feature_list_pred, axis=0)
print(feature_combined_pred.shape) # (2447, 299, 40)
dataset_pred = MyDataset(feature_combined_pred,np.empty((2447, 0)))

pred_loader = torch.utils.data.DataLoader(dataset_pred, batch_size=batch_size, shuffle=False)
# Out:
# (2447, 299, 40)

# %%
def set_model(input_channels=1, num_classes=4):
    model = models.resnet34(pretrained=False)
    # 修改第一层卷积以适应输入数据的通道数
    model.conv1 = nn.Conv2d(input_channels, 64, kernel_size=7, stride=2, padding=3, bias=False)
    # 修改全连接层输出为四个类别
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    return model

model = set_model(input_channels=1, num_classes=4)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
optimizer = optim.AdamW(model.parameters(), lr=0.0005)
criterion = nn.CrossEntropyLoss()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def train_model(num_epochs, train_loader, test_loader):
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        print(f'Epoch {epoch+1}, Loss: {total_loss / len(train_loader)}')
        evaluate_model(test_loader)

def evaluate_model(test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f'Accuracy on test set: {100 * correct / total}%')

train_model(num_epochs=26, train_loader=train_loader, test_loader=test_loader)
# Out:
# Epoch 1, Loss: 0.9123379805913339
# Accuracy on test set: 71.87324733595065%
# Epoch 2, Loss: 0.656989518724955
# Accuracy on test set: 67.41446999439148%
# Epoch 3, Loss: 0.577745706989215
# Accuracy on test set: 74.81772293886708%
# Epoch 4, Loss: 0.5267956749751017
# Accuracy on test set: 72.32192933258553%
# Epoch 5, Loss: 0.47624205843760414
# Accuracy on test set: 76.38810992708918%
# Epoch 6, Loss: 0.4439235137059138
# Accuracy on test set: 75.79921480650589%
# Epoch 7, Loss: 0.4148001302893345
# Accuracy on test set: 79.92148065058889%
# Epoch 8, Loss: 0.36882972224400595
# Accuracy on test set: 78.79977565900168%
# Epoch 9, Loss: 0.33835582458055935
# Accuracy on test set: 77.20134604598991%
# Epoch 10, Loss: 0.2996614911235296
# Accuracy on test set: 80.4823331463825%
# Epoch 11, Loss: 0.2852617377272019
# Accuracy on test set: 77.7902411665732%
# Epoch 12, Loss: 0.24660937281755302
# Accuracy on test set: 81.15535614133483%
# Epoch 13, Loss: 0.24330671549989627
# Accuracy on test set: 78.40717891194616%
# Epoch 14, Loss: 0.2098058115404386
# Accuracy on test set: 80.11777902411666%
# Epoch 15, Loss: 0.19517138846791707
# Accuracy on test set: 79.89343802579921%
# Epoch 16, Loss: 0.1695816458417819
# Accuracy on test set: 80.7627593942793%
# Epoch 17, Loss: 0.15737761118664192
# Accuracy on test set: 80.59450364554122%
# Epoch 18, Loss: 0.15014408116157238
# Accuracy on test set: 77.28547392035894%
# Epoch 19, Loss: 0.14295966447545932
# Accuracy on test set: 80.84688726864835%
# Epoch 20, Loss: 0.11468069288306511
# Accuracy on test set: 78.79977565900168%
# Epoch 21, Loss: 0.11821597086695525
# Accuracy on test set: 83.70723499719574%
# Epoch 22, Loss: 0.11510103423721516
# Accuracy on test set: 80.2019068984857%
# Epoch 23, Loss: 0.09605635665357112
# Accuracy on test set: 83.51093662366797%
# Epoch 24, Loss: 0.08705700292753485
# Accuracy on test set: 83.25855300056085%
# Epoch 25, Loss: 0.08030713231374438
# Accuracy on test set: 81.57599551318003%
# Epoch 26, Loss: 0.0858885943531417
# Accuracy on test set: 84.04374649467191%

# %%
import pandas as pd
predictions = []
def predict_output(model,predict_loader,predictions):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)  # to GPU or CPU
    model.eval()
    with torch.no_grad():
        for inputs, labels in pred_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
#             print(predicted)

            if predicted.requires_grad:
                predicted = predicted.detach() # detach gradient computing
            if predicted.is_cuda:
                predicted = predicted.cpu()
                
            predicted = predicted.numpy()
#             print(predicted)
            predictions.append(predicted)
#             print(len(predicted))
#             print(len(predictions))
            concatenated_pred = np.concatenate(predictions, axis=0)
            
    return concatenated_pred
            
concatenated_pred = predict_output(model,pred_loader,predictions)

# print(concatenated_pred)
submission_df = pd.DataFrame({
    "id": range(len(concatenated_pred)),  # 创建一个从 0 到 预测数-1 的序列
    "category": concatenated_pred  # 使用预测结果填充类别列
})

# 保存 DataFrame 到 CSV 文件
submission_file_path = '/kaggle/working/submissionnnn.csv'  # 指定文件保存路径
submission_df.to_csv(submission_file_path, index=False)  # 确保不保存索引列

print(f"CSV file saved to {submission_file_path}")
# Out:
# CSV file saved to /kaggle/working/submissionnnn.csv
